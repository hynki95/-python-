# %%
import pandas as pd
읽기=pd.read_csv('./NHIS_OPEN_T20_2008.csv',engine="python")

# %%
읽기
# Out:
#          기준년도  가입자 일련번호  진료내역일련번호  성별코드  연령대코드  시도코드    요양개시일자  서식코드  진료과목코드  \
# 0        2008    436625         1     2     13    26  20081208     3       1
# 1        2008    536663         2     2     10    26  20081224     3       1
# 2        2008    718041         3     2      8    26  20081208     3       1
# 3        2008    435154         4     1      9    26  20081210     3       1
# 4        2008    435154         5     1      9    26  20081226     3       1
# 5        2008    435154         6     1      9    26  20081229     3       1
# 6        2008    441547         7     1      9    26  20081201     3       1
# 7        2008    441547         8     1      9    26  20081212     3       1
# 8        2008    432029         9     1      5    26  20081230     3       1
# 9        2008     87953        10     2     10    47  20081202     3      10
# 10       2008    535215        11     2     12    47  20081202     3      10
# ...

# %%
읽기.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
# 기준년도          1048575 non-null int64
# 가입자 일련번호      1048575 non-null int64
# 진료내역일련번호      1048575 non-null int64
# 성별코드          1048575 non-null int64
# 연령대코드         1048575 non-null int64
# 시도코드          1048575 non-null int64
# 요양개시일자        1048575 non-null int64
# 서식코드          1048575 non-null int64
# 진료과목코드        1048575 non-null int64
# 주상병코드         1048575 non-null object
# 부상병코드         687452 non-null object
# 요양일수          1048575 non-null int64
# 입내원일수         1048575 non-null int64
# 심결가산율         1048575 non-null int64
# 심결요양급여비용총액    1048575 non-null int64
# 심결본인부담금       1048575 non-null int64
# 심결보험자부담금      1048575 non-null int64
# 심결씨티총액        1048575 non-null int64
# 심결엠알아이총액      1048575 non-null int64
# 총처방일수         1048572 non-null float64
# 데이터 기준일자      1048575 non-null int64
# dtypes: float64(1), int64(18), object(2)
# ...

# %%
읽기.describe()
# Out:
#             기준년도      가입자 일련번호      진료내역일련번호          성별코드         연령대코드  \
# count  1048575.0  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean      2008.0  5.191164e+05  5.242880e+05  1.572918e+00  8.834989e+00
# std          0.0  2.915483e+05  3.026977e+05  4.946546e-01  4.911592e+00
# min       2008.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2008.0  2.649740e+05  2.621445e+05  1.000000e+00  4.000000e+00
# 50%       2008.0  5.221270e+05  5.242880e+05  2.000000e+00  1.000000e+01
# 75%       2008.0  7.769710e+05  7.864315e+05  2.000000e+00  1.300000e+01
# max       2008.0  1.008627e+06  1.048575e+06  2.000000e+00  1.800000e+01
#
#                시도코드        요양개시일자          서식코드        진료과목코드          요양일수  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   3.319900e+01  2.008088e+07  3.030715e+00  7.639192e+00  1.116340e+00
# std    1.240923e+01  3.865650e+02  5.174992e-01  5.936847e+00  1.389096e+00
# ...

# %%
읽기.head(3)
# Out:
#    기준년도  가입자 일련번호  진료내역일련번호  성별코드  연령대코드  시도코드    요양개시일자  서식코드  진료과목코드 주상병코드  \
# 0  2008    436625         1     2     13    26  20081208     3       1   J42
# 1  2008    536663         2     2     10    26  20081224     3       1  J450
# 2  2008    718041         3     2      8    26  20081208     3       1  J041
#
#      ...    요양일수  입내원일수  심결가산율  심결요양급여비용총액  심결본인부담금  심결보험자부담금  심결씨티총액  \
# 0    ...       1      1     15        8350     2500      5850       0
# 1    ...       1      1     15        8420     2500      5920       0
# 2    ...       1      1     15       13650     4000      9650       0
#
#    심결엠알아이총액  총처방일수  데이터 기준일자
# 0         0    7.0  20151220
# 1         0    6.0  20151220
# 2         0    1.0  20151220
#
# [3 rows x 21 columns]
