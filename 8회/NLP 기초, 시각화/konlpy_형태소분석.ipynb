# %% [markdown]
# # KoNLPy

# %% [markdown]
# [KoNLPy 공식 홈페이지](https://konlpy-ko.readthedocs.io/ko/v0.4.3/)

# %% [markdown]
# 1. [JAVA JDK 설치](http://www.oracle.com/technetwork/java/javase/downloads/index.html) ---- [한글 설명](http://limkydev.tistory.com/61)
# 2. [JAVA_HOME 경로설정](https://docs.oracle.com/cd/E19182-01/820-7851/inst_cli_jdk_javahome_t/index.html)
# 3. [JPype 설치](https://www.lfd.uci.edu/~gohlke/pythonlibs/#jpype)
#     1. JPype1‑0.6.2‑cp36‑cp36m‑win_amd64.whl 설치파일 다운로드
#     2. 설치파일 쉘과 동일 위치 설정
#     3. pip install JPype1‑0.6.2‑cp36‑cp36m‑win_amd64.whl
# 4. KoNLPy 설치 : pip install konlpy

# %% [markdown]
# ---

# %% [markdown]
# # wordcloud

# %% [markdown]
# [word colud 공식홈페이지](https://amueller.github.io/word_cloud/index.html)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


from wordcloud import WordCloud

# %%
text = open("우리.txt",encoding = "utf-8").read()

# %%
text
# Out:
# '이예지, 박주희, 정일균, 차재성, 엄유진, ... 님과 카카오톡 대화\n저장한 날짜 : 2018-01-11 17:33:30\n\n--------------- 2018년 1월 10일 수요일 ---------------\n정일균님이 차재성님, 차재성님, 조현기님, 차재성님, 조현기님, 이예지님, 차재성님, 조현기님, 이예지님, 엄유진님, 차재성님, 조현기님, 이예지님, 엄유진님, 박주희님, 차재성님, 조현기님, 이예지님, 엄유진님, 박주희님, 민정원님을 초대하였습니다.\n[정일균] [오후 5:19] 자료업로드\n[정일균] [오후 5:19] http://www.ekn.kr/news/article.html?no=254131\n[조현기] [오후 5:24] [FILE] 회의록180109.docx (20.13KB)\n[조현기] [오후 5:54] http://franchise.ftc.go.kr/user/extra/main/62/firMst/list/jsp/LayOutPage.do\n[조현기] [오후 5:57] YOLO족, 가심비, 플라시보 소비, 엠티, MT, 가성비, 싸다, 맛, 가볍다, 쓰다, 수입맥주, 코끼리, 녹색, 초록색, 필리, 발포주, 맥주, 소맥, 도수, 쓴맛, 알코올, 알콜, 주류, 즐겁다, 신나다, 취한다, 청량감, 혼술, 혼맥, 상큼, 상큼한, 상큼하다, 청정, 깨끗함, 물탐, 물탄맛, 물탔네, 물, 피츠, 호랑이, 조정석, 망고링고, 써머스비, 주류세, 발아, 세금, 비싸다, 탕진, 탕진잼, 20대, 라이프 스타일, 소비 패턴, 달다, 독서실, 소음, 카공, 원두, 다이어리, 득템, 개이득, 굳, 분위기, 음악, 의자, 조명, 제3맥주, 홀더, 컵홀더, 테이크 아웃, 컵 홀더, 테이크아웃, 코끼리맥주, 즐기다, 아아, 한잔, 혼자, 근처, 가깝다, 행복, 편하다, 지렸다, 퇴근, 추억, 수업, 오지구요, 오졌다, 오졌다리, 실화냐, 린정, 커엽, 인정, 연비, 승차감, 그립감, 엔진, 외국인, 외국인필라이트, 필라이트에 대한 외국인의 견해, 스트레스, 조아, 조하, 됴아, 뎌아, 개쩔어, 쩔어, 헐, 대박, 대박사건, 프라임드래프트, 프라임 드래프트,맥주축제,클럽,맥주 판매, 치맥, 탄산주, 알쓰, 홈술, 홈술족, 홈술 인테리어, 홈바, 탕진잼, 시발비용,취향, 취향 타다, 혼맥족, 에일, 라거, IPA, 크래프트맥주, 맥주전용잔, 맥주잔 디자인, 맥주잔, 전용잔, 북토크, 강연, 작가, 작가와의 대화, 소설작가, 작가대화, 전공강의, 카페강의, 카페수업, 카페교류, 교환, 교류, 북클럽, 책카페, 책읽기, 기프티콘, 기프트카드, 사이렌 오더, 응원 선물, 팀플, 개인 작업, 개인 공부, 소음, 예민, 눈치, 분위기, 무드, 느낌, 노맛, 노잼, 노어이, 디저트, 케이꾸, 창업자, 창업, 귀엽다, 갤러리아, 물맥주, 낮은농도, 옅은, 싼맛, 싸구려, 구리다, 구리네, 목넘김, 비추, 강추, 탈락, 성공, 추억, 새내기, 대학생, 1학년, 모임, 2학년, 3학년, 4학년, 고시생, 공무원, 핫플, 핫하다, 피곤해, 열공, 혈공, 가즈아, ㅇㅈ , 힐링, 취업, 연애, 놀기, 먹기, 여행, 나를위한, 선물, 나만의시간, 나혼자, 혼자, 거지, 돈없어, 돈없음, 버겁다, 지친다, 지쳐, 밤샘, 내적댄스, 외롭다, 첫술, 인생첫술, 인생술, 첫맥주, 인생맥주, 왜마셔, 술왜마셔, 과시, 셀카, 막장, 노답, 군대생각, 노키즈존, 애들, 시끄러워, 신메뉴, 월요일, 월욜, 화욜, 수욜, 목욜, 금욜, 불금, 불토, 월요병, 점심, 저녁, 든든, 비트코인, 해시태그, #, 무거운, 중후한, 진한, 찐한, 반오십, 민짜, 민증검사, 일탈, \n--------------- 2018년 1월 11일 목요일 ---------------\n[차재성] [오전 10:17] [FILE] 맥주.xlsx (10.44KB)\n[차재성] [오전 10:17] [FILE] 제네시스.xlsx (8.93KB)\n[차재성] [오전 10:17] [FILE] 커피 브랜드.xlsx (9.91KB)\n[차재성] [오전 10:17] [FILE] 회의록180109.docx (24.35KB)\n[조현기] [오전 10:59] [FILE] 자료.xlsx (13.63KB)'

# %%
wordcolud_1 = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf').generate(text) # WordCloud 자체가 형태소 분석하여 빈도수 계산

# %%
wordcolud_1.words_
# Out:
# {'10일': 0.2,
#  '13KB': 0.2,
#  '1월': 0.4,
#  '2018년': 0.4,
#  '20대': 0.2,
#  'FILE': 0.2,
#  'IPA': 0.2,
#  'LayOutPage': 0.2,
#  'MT': 0.2,
#  'YOLO족': 0.2,
#  'article': 0.2,
#  'docx': 0.4,
#  'ekn': 0.2,
#  'extra': 0.2,
#  'firMst': 0.2,
#  'franchise': 0.2,
#  'ftc': 0.2,
#  'go': 0.2,
#  'html': 0.2,
#  'jsp': 0.2,
#  'kr': 0.4,
#  'list': 0.2,
#  'main': 0.2,
#  'news': 0.2,
#  'user': 0.2,
#  'xlsx': 0.8,
#  '가깝다': 0.2,
#  '가볍다': 0.2,
#  '가성비': 0.2,
#  '가심비': 0.2,
#  '강연': 0.2,
#  '개이득': 0.2,
#  '개인': 0.4,
#  '개쩔어': 0.2,
#  '견해': 0.2,
#  '교류': 0.2,
#  '교환': 0.2,
#  '그립감': 0.2,
#  '근처': 0.2,
#  '기프트카드': 0.2,
#  '기프티콘': 0.2,
#  '깨끗함': 0.2,
#  '날짜': 0.2,
#  '녹색': 0.2,
#  '님과': 0.2,
#  '다이어리': 0.2,
#  '달다': 0.2,
#  '대박': 0.2,
#  '대박사건': 0.2,
#  '대한': 0.2,
#  '대화': 0.4,
#  '뎌아': 0.2,
#  '도수': 0.2,
#  '독서실': 0.2,
#  '됴아': 0.2,
#  '드래프트': 0.2,
#  '득템': 0.2,
#  '디자인': 0.2,
#  '라거': 0.2,
#  '라이프': 0.2,
#  '린정': 0.2,
#  '망고링고': 0.2,
#  '맥주': 0.6,
#  '맥주잔': 0.4,
#  '맥주전용잔': 0.2,
#  '맥주축제': 0.2,
#  '물탄맛': 0.2,
#  '물탐': 0.2,
#  '물탔네': 0.2,
#  '민정원님을': 0.2,
#  '박주희': 0.2,
#  '박주희님': 0.4,
#  '발아': 0.2,
#  '발포주': 0.2,
#  '북클럽': 0.2,
#  '북토크': 0.2,
#  '분위기': 0.4,
#  '비싸다': 0.2,
#  '상큼': 0.2,
#  '상큼하다': 0.2,
#  '상큼한': 0.2,
#  '선물': 0.4,
#  '세금': 0.2,
#  '소맥': 0.2,
#  '소비': 0.4,
#  '소설작가': 0.2,
#  '소음': 0.4,
#  '수업': 0.2,
#  '수요일': 0.2,
#  '수입맥주': 0.2,
#  '스타일': 0.2,
#  '스트레스': 0.2,
#  '승차감': 0.2,
#  '시발비용': 0.2,
#  '신나다': 0.2,
#  '실화냐': 0.2,
#  '싸다': 0.2,
#  '써머스비': 0.2,
#  '쓰다': 0.2,
#  '쓴맛': 0.2,
#  '아아': 0.2,
#  '아웃': 0.2,
#  '알쓰': 0.2,
#  '알코올': 0.2,
#  '알콜': 0.2,
#  '엄유진': 0.2,
#  '에일': 0.2,
#  '엔진': 0.2,
#  '엠티': 0.2,
#  '연비': 0.2,
#  '오전 FILE': 1.0,
#  '오졌다': 0.2,
#  '오졌다리': 0.2,
#  '오지구요': 0.2,
#  '오후': 1.0,
#  '외국인': 0.2,
#  '외국인의': 0.2,
#  '외국인필라이트': 0.2,
#  '원두': 0.2,
#  '음악': 0.2,
#  '의자': 0.2,
#  '이예지': 0.2,
#  '이예지님 엄유진님': 0.6,
#  '인정': 0.2,
#  '인테리어': 0.2,
#  '자료업로드': 0.2,
#  '작가': 0.2,
#  '작가대화': 0.2,
#  '작가와의': 0.2,
#  '저장한': 0.2,
#  '전공강의': 0.2,
#  '전용잔': 0.2,
#  '정일균': 0.6,
#  '정일균님이': 0.2,
#  '제3맥주': 0.2,
#  '조명': 0.2,
#  '조아': 0.2,
#  '조정석': 0.2,
#  '조하': 0.2,
#  '조현기': 0.8,
#  '조현기님 이예지님': 0.8,
#  '주류': 0.2,
#  '주류세': 0.2,
#  '즐겁다': 0.2,
#  '즐기다': 0.2,
#  '지렸다': 0.2,
#  '쩔어': 0.2,
#  '차재성': 0.2,
#  '차재성 오전': 0.8,
#  '차재성님': 0.2,
#  '차재성님 조현기님': 1.0,
#  '책읽기': 0.2,
#  '책카페': 0.2,
#  '청량감': 0.2,
#  '청정': 0.2,
#  '초대하였습니다': 0.2,
#  '초록색': 0.2,
#  '추억': 0.4,
#  '취한다': 0.2,
#  '취향': 0.4,
#  '치맥': 0.2,
#  '카공': 0.2,
#  '카카오톡': 0.2,
#  '카페강의': 0.2,
#  '카페교류': 0.2,
#  '카페수업': 0.2,
#  '커엽': 0.2,
#  '컵홀더': 0.2,
#  '코끼리': 0.2,
#  '코끼리맥주': 0.2,
#  '크래프트맥주': 0.2,
#  '클럽': 0.2,
#  '타다': 0.2,
#  '탄산주': 0.2,
#  '탕진': 0.2,
#  '탕진잼': 0.4,
#  '테이크': 0.2,
#  '테이크아웃': 0.2,
#  '퇴근': 0.2,
#  '판매': 0.2,
#  '패턴': 0.2,
#  '편하다': 0.2,
#  '프라임': 0.2,
#  '프라임드래프트': 0.2,
#  '플라시보': 0.2,
#  '피츠': 0.2,
#  '필라이트에': 0.2,
#  '필리': 0.2,
#  '한잔': 0.2,
#  '행복': 0.2,
#  '호랑이': 0.2,
#  '혼맥': 0.2,
#  '혼맥족': 0.2,
#  '혼술': 0.2,
#  '혼자': 0.4,
#  '홀더': 0.4,
#  '홈바': 0.2,
#  '홈술': 0.4,
#  '홈술족': 0.2,
#  '회의록180109': 0.4}

# %%
plt.figure(figsize=(12,12))
plt.imshow(wordcolud_1)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# %reset

# %% [markdown]
# ## Alice 데이터

# %%
import numpy as np
from PIL import Image

from wordcloud import STOPWORDS
import matplotlib.pyplot as plt

# %%
text = open("우리.txt",encoding = "utf-8").read()

# %%
text
# Out:
# '이예지, 박주희, 정일균, 차재성, 엄유진, ... 님과 카카오톡 대화\n저장한 날짜 : 2018-01-11 17:33:30\n\n--------------- 2018년 1월 10일 수요일 ---------------\n정일균님이 차재성님, 차재성님, 조현기님, 차재성님, 조현기님, 이예지님, 차재성님, 조현기님, 이예지님, 엄유진님, 차재성님, 조현기님, 이예지님, 엄유진님, 박주희님, 차재성님, 조현기님, 이예지님, 엄유진님, 박주희님, 민정원님을 초대하였습니다.\n[정일균] [오후 5:19] 자료업로드\n[정일균] [오후 5:19] http://www.ekn.kr/news/article.html?no=254131\n[조현기] [오후 5:24] [FILE] 회의록180109.docx (20.13KB)\n[조현기] [오후 5:54] http://franchise.ftc.go.kr/user/extra/main/62/firMst/list/jsp/LayOutPage.do\n[조현기] [오후 5:57] YOLO족, 가심비, 플라시보 소비, 엠티, MT, 가성비, 싸다, 맛, 가볍다, 쓰다, 수입맥주, 코끼리, 녹색, 초록색, 필리, 발포주, 맥주, 소맥, 도수, 쓴맛, 알코올, 알콜, 주류, 즐겁다, 신나다, 취한다, 청량감, 혼술, 혼맥, 상큼, 상큼한, 상큼하다, 청정, 깨끗함, 물탐, 물탄맛, 물탔네, 물, 피츠, 호랑이, 조정석, 망고링고, 써머스비, 주류세, 발아, 세금, 비싸다, 탕진, 탕진잼, 20대, 라이프 스타일, 소비 패턴, 달다, 독서실, 소음, 카공, 원두, 다이어리, 득템, 개이득, 굳, 분위기, 음악, 의자, 조명, 제3맥주, 홀더, 컵홀더, 테이크 아웃, 컵 홀더, 테이크아웃, 코끼리맥주, 즐기다, 아아, 한잔, 혼자, 근처, 가깝다, 행복, 편하다, 지렸다, 퇴근, 추억, 수업, 오지구요, 오졌다, 오졌다리, 실화냐, 린정, 커엽, 인정, 연비, 승차감, 그립감, 엔진, 외국인, 외국인필라이트, 필라이트에 대한 외국인의 견해, 스트레스, 조아, 조하, 됴아, 뎌아, 개쩔어, 쩔어, 헐, 대박, 대박사건, 프라임드래프트, 프라임 드래프트,맥주축제,클럽,맥주 판매, 치맥, 탄산주, 알쓰, 홈술, 홈술족, 홈술 인테리어, 홈바, 탕진잼, 시발비용,취향, 취향 타다, 혼맥족, 에일, 라거, IPA, 크래프트맥주, 맥주전용잔, 맥주잔 디자인, 맥주잔, 전용잔, 북토크, 강연, 작가, 작가와의 대화, 소설작가, 작가대화, 전공강의, 카페강의, 카페수업, 카페교류, 교환, 교류, 북클럽, 책카페, 책읽기, 기프티콘, 기프트카드, 사이렌 오더, 응원 선물, 팀플, 개인 작업, 개인 공부, 소음, 예민, 눈치, 분위기, 무드, 느낌, 노맛, 노잼, 노어이, 디저트, 케이꾸, 창업자, 창업, 귀엽다, 갤러리아, 물맥주, 낮은농도, 옅은, 싼맛, 싸구려, 구리다, 구리네, 목넘김, 비추, 강추, 탈락, 성공, 추억, 새내기, 대학생, 1학년, 모임, 2학년, 3학년, 4학년, 고시생, 공무원, 핫플, 핫하다, 피곤해, 열공, 혈공, 가즈아, ㅇㅈ , 힐링, 취업, 연애, 놀기, 먹기, 여행, 나를위한, 선물, 나만의시간, 나혼자, 혼자, 거지, 돈없어, 돈없음, 버겁다, 지친다, 지쳐, 밤샘, 내적댄스, 외롭다, 첫술, 인생첫술, 인생술, 첫맥주, 인생맥주, 왜마셔, 술왜마셔, 과시, 셀카, 막장, 노답, 군대생각, 노키즈존, 애들, 시끄러워, 신메뉴, 월요일, 월욜, 화욜, 수욜, 목욜, 금욜, 불금, 불토, 월요병, 점심, 저녁, 든든, 비트코인, 해시태그, #, 무거운, 중후한, 진한, 찐한, 반오십, 민짜, 민증검사, 일탈, \n--------------- 2018년 1월 11일 목요일 ---------------\n[차재성] [오전 10:17] [FILE] 맥주.xlsx (10.44KB)\n[차재성] [오전 10:17] [FILE] 제네시스.xlsx (8.93KB)\n[차재성] [오전 10:17] [FILE] 커피 브랜드.xlsx (9.91KB)\n[차재성] [오전 10:17] [FILE] 회의록180109.docx (24.35KB)\n[조현기] [오전 10:59] [FILE] 자료.xlsx (13.63KB)'

# %%
# 사진 데이터를 pil 패키지의 Image를 활용해서 0~255 데이터로 읽어왔다.
alice_mask = np.array(Image.open('사과.jpg'))

# %%
alice_mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
# plt.imshow()는 수치 데이터 -> image데이터로 변환해줌
plt.imshow(alice_mask, cmap=plt.cm.gray)
plt.axis('off')
# Out:
# (-0.5, 419.5, 287.5, -0.5)

# %%
## 많은 빈도로 나오는 관사, 전치사 모아놓은 데이터
stopwords =set(STOPWORDS)
STOPWORDS
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
#  "let's",
#  'like',
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'r',
#  'same',
#  'shall',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  'than',
#  'that',
#  "that's",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  "there's",
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'when',
#  "when's",
#  'where',
#  "where's",
#  'which',
#  'while',
#  'who',
#  "who's",
#  'whom',
#  'why',
#  "why's",
#  'with',
#  "won't",
#  'would',
#  "wouldn't",
#  'www',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
stopwords = set(STOPWORDS)
stopwords.add("오후")

# %%
wordcolud_2 = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',background_color = 'white', max_words=2000, mask=alice_mask,
                       stopwords=stopwords)

wordcolud_2 = wordcolud_2.generate(text)

wordcolud_2.words_
# Out:
# {'10일': 0.2,
#  '11일': 0.2,
#  '13KB': 0.2,
#  '1월': 0.4,
#  '1학년': 0.2,
#  '2018년': 0.4,
#  '20대': 0.2,
#  '2학년': 0.2,
#  '35KB': 0.2,
#  '3학년': 0.2,
#  '44KB': 0.2,
#  '4학년': 0.2,
#  '63KB': 0.2,
#  '91KB': 0.2,
#  '93KB': 0.2,
#  'FILE': 0.2,
#  'IPA': 0.2,
#  'LayOutPage': 0.2,
#  'MT': 0.2,
#  'YOLO족': 0.2,
#  'article': 0.2,
#  'docx': 0.4,
#  'ekn': 0.2,
#  'extra': 0.2,
#  'firMst': 0.2,
#  'franchise': 0.2,
#  'ftc': 0.2,
#  'go': 0.2,
#  'html': 0.2,
#  'jsp': 0.2,
#  'kr': 0.4,
#  'list': 0.2,
#  'main': 0.2,
#  'news': 0.2,
#  'user': 0.2,
#  'xlsx': 0.8,
#  'ㅇㅈ': 0.2,
#  '가깝다': 0.2,
#  '가볍다': 0.2,
#  '가성비': 0.2,
#  '가심비': 0.2,
#  '가즈아': 0.2,
#  '강연': 0.2,
#  '강추': 0.2,
#  '개이득': 0.2,
#  '개인': 0.4,
#  '개쩔어': 0.2,
#  '갤러리아': 0.2,
#  '거지': 0.2,
#  '견해': 0.2,
#  '고시생': 0.2,
#  '공무원': 0.2,
#  '공부': 0.2,
#  '과시': 0.2,
#  '교류': 0.2,
#  '교환': 0.2,
#  '구리네': 0.2,
#  '구리다': 0.2,
#  '군대생각': 0.2,
#  '귀엽다': 0.2,
#  '그립감': 0.2,
#  '근처': 0.2,
#  '금욜': 0.2,
#  '기프트카드': 0.2,
#  '기프티콘': 0.2,
#  '깨끗함': 0.2,
#  '나를위한': 0.2,
#  '나만의시간': 0.2,
#  '나혼자': 0.2,
#  '날짜': 0.2,
#  '낮은농도': 0.2,
#  '내적댄스': 0.2,
#  '노답': 0.2,
#  '노맛': 0.2,
#  '노어이': 0.2,
#  '노잼': 0.2,
#  '노키즈존': 0.2,
#  '녹색': 0.2,
#  '놀기': 0.2,
#  '눈치': 0.2,
#  '느낌': 0.2,
#  '님과': 0.2,
#  '다이어리': 0.2,
#  '달다': 0.2,
#  '대박': 0.2,
#  '대박사건': 0.2,
#  '대학생': 0.2,
#  '대한': 0.2,
#  '대화': 0.4,
#  '뎌아': 0.2,
#  '도수': 0.2,
#  '독서실': 0.2,
#  '돈없어': 0.2,
#  '돈없음': 0.2,
#  '됴아': 0.2,
#  '드래프트': 0.2,
#  '득템': 0.2,
#  '든든': 0.2,
#  '디자인': 0.2,
#  '디저트': 0.2,
#  '라거': 0.2,
#  '라이프': 0.2,
#  '린정': 0.2,
#  '막장': 0.2,
#  '망고링고': 0.2,
#  '맥주': 0.6,
#  '맥주잔': 0.4,
#  '맥주전용잔': 0.2,
#  '맥주축제': 0.2,
#  '먹기': 0.2,
#  '모임': 0.2,
#  '목넘김': 0.2,
#  '목요일': 0.2,
#  '목욜': 0.2,
#  '무거운': 0.2,
#  '무드': 0.2,
#  '물맥주': 0.2,
#  '물탄맛': 0.2,
#  '물탐': 0.2,
#  '물탔네': 0.2,
#  '민정원님을': 0.2,
#  '민증검사': 0.2,
#  '민짜': 0.2,
#  '박주희': 0.2,
#  '박주희님': 0.4,
#  '반오십': 0.2,
#  '발아': 0.2,
#  '발포주': 0.2,
#  '밤샘': 0.2,
#  '버겁다': 0.2,
#  '북클럽': 0.2,
#  '북토크': 0.2,
#  '분위기': 0.4,
#  '불금': 0.2,
#  '불토': 0.2,
#  '브랜드': 0.2,
#  '비싸다': 0.2,
#  '비추': 0.2,
#  '비트코인': 0.2,
#  '사이렌': 0.2,
#  '상큼': 0.2,
#  '상큼하다': 0.2,
#  '상큼한': 0.2,
#  '새내기': 0.2,
#  '선물': 0.4,
#  '성공': 0.2,
#  '세금': 0.2,
#  '셀카': 0.2,
#  '소맥': 0.2,
#  '소비': 0.4,
#  '소설작가': 0.2,
#  '소음': 0.4,
#  '수업': 0.2,
#  '수요일': 0.2,
#  '수욜': 0.2,
#  '수입맥주': 0.2,
#  '술왜마셔': 0.2,
#  '스타일': 0.2,
#  '스트레스': 0.2,
#  '승차감': 0.2,
#  '시끄러워': 0.2,
#  '시발비용': 0.2,
#  '신나다': 0.2,
#  '신메뉴': 0.2,
#  '실화냐': 0.2,
#  '싸구려': 0.2,
#  '싸다': 0.2,
#  '싼맛': 0.2,
#  '써머스비': 0.2,
#  '쓰다': 0.2,
#  '쓴맛': 0.2,
#  '아아': 0.2,
#  '아웃': 0.2,
#  '알쓰': 0.2,
#  '알코올': 0.2,
#  '알콜': 0.2,
#  '애들': 0.2,
#  '엄유진': 0.2,
#  '에일': 0.2,
#  '엔진': 0.2,
#  '엠티': 0.2,
#  '여행': 0.2,
#  '연비': 0.2,
#  '연애': 0.2,
#  '열공': 0.2,
#  '옅은': 0.2,
#  '예민': 0.2,
#  '오더': 0.2,
#  '오전 FILE': 1.0,
#  '오졌다': 0.2,
#  '오졌다리': 0.2,
#  '오지구요': 0.2,
#  '왜마셔': 0.2,
#  '외국인': 0.2,
#  '외국인의': 0.2,
#  '외국인필라이트': 0.2,
#  '외롭다': 0.2,
#  '원두': 0.2,
#  '월요병': 0.2,
#  '월요일': 0.2,
#  '월욜': 0.2,
#  '음악': 0.2,
#  '응원': 0.2,
#  '의자': 0.2,
#  '이예지': 0.2,
#  '이예지님 엄유진님': 0.6,
#  '인생맥주': 0.2,
#  '인생술': 0.2,
#  '인생첫술': 0.2,
#  '인정': 0.2,
#  '인테리어': 0.2,
#  '일탈': 0.2,
#  '자료': 0.2,
#  '자료업로드': 0.2,
#  '작가': 0.2,
#  '작가대화': 0.2,
#  '작가와의': 0.2,
#  '작업': 0.2,
#  '저녁': 0.2,
#  '저장한': 0.2,
#  '전공강의': 0.2,
#  '전용잔': 0.2,
#  '점심': 0.2,
#  '정일균': 0.6,
#  '정일균님이': 0.2,
#  '제3맥주': 0.2,
#  '제네시스': 0.2,
#  '조명': 0.2,
#  '조아': 0.2,
#  '조정석': 0.2,
#  '조하': 0.2,
#  '조현기': 0.8,
#  '조현기님 이예지님': 0.8,
#  '주류': 0.2,
#  '주류세': 0.2,
#  '중후한': 0.2,
#  '즐겁다': 0.2,
#  '즐기다': 0.2,
#  '지렸다': 0.2,
#  '지쳐': 0.2,
#  '지친다': 0.2,
#  '진한': 0.2,
#  '쩔어': 0.2,
#  '찐한': 0.2,
#  '차재성': 0.2,
#  '차재성 오전': 0.8,
#  '차재성님': 0.2,
#  '차재성님 조현기님': 1.0,
#  '창업': 0.2,
#  '창업자': 0.2,
#  '책읽기': 0.2,
#  '책카페': 0.2,
#  '첫맥주': 0.2,
#  '첫술': 0.2,
#  '청량감': 0.2,
#  '청정': 0.2,
#  '초대하였습니다': 0.2,
#  '초록색': 0.2,
#  '추억': 0.4,
#  '취업': 0.2,
#  '취한다': 0.2,
#  '취향': 0.4,
#  '치맥': 0.2,
#  '카공': 0.2,
#  '카카오톡': 0.2,
#  '카페강의': 0.2,
#  '카페교류': 0.2,
#  '카페수업': 0.2,
#  '커엽': 0.2,
#  '커피': 0.2,
#  '컵홀더': 0.2,
#  '케이꾸': 0.2,
#  '코끼리': 0.2,
#  '코끼리맥주': 0.2,
#  '크래프트맥주': 0.2,
#  '클럽': 0.2,
#  '타다': 0.2,
#  '탄산주': 0.2,
#  '탈락': 0.2,
#  '탕진': 0.2,
#  '탕진잼': 0.4,
#  '테이크': 0.2,
#  '테이크아웃': 0.2,
#  '퇴근': 0.2,
#  '팀플': 0.2,
#  '판매': 0.2,
#  '패턴': 0.2,
#  '편하다': 0.2,
#  '프라임': 0.2,
#  '프라임드래프트': 0.2,
#  '플라시보': 0.2,
#  '피곤해': 0.2,
#  '피츠': 0.2,
#  '필라이트에': 0.2,
#  '필리': 0.2,
#  '한잔': 0.2,
#  '핫플': 0.2,
#  '핫하다': 0.2,
#  '해시태그': 0.2,
#  '행복': 0.2,
#  '혈공': 0.2,
#  '호랑이': 0.2,
#  '혼맥': 0.2,
#  '혼맥족': 0.2,
#  '혼술': 0.2,
#  '혼자': 0.4,
#  '홀더': 0.4,
#  '홈바': 0.2,
#  '홈술': 0.4,
#  '홈술족': 0.2,
#  '화욜': 0.2,
#  '회의록180109': 0.4,
#  '힐링': 0.2}

# %%
plt.imshow(wordcolud_2)
plt.axis('off')
# Out:
# (-0.5, 419.5, 287.5, -0.5)

# %%
plt.figure(figsize=(12,12))
plt.imshow(wordcolud_2)

plt.axis('off')
# Out:
# (-0.5, 419.5, 287.5, -0.5)

# %%
text = open('우리.txt',encoding="utf-8").read()

alice_coloring = np.array(Image.open('사과.jpg'))


stopwords = set(STOPWORDS)
stopwords.add('조현기')  #said 카운팅 안하고 싶다..

# %%
plt.imshow(alice_coloring)

# %%
wordcolud_3 = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',background_color='black', max_words=1000, mask=alice_coloring, 
                       stopwords = stopwords, max_font_size=30, random_state=32)

wordcolud_3.generate(text)

# %%
#plt.figure(figsize=(12,12))
plt.imshow(wordcolud_3)
plt.axis('off')
# Out:
# (-0.5, 419.5, 287.5, -0.5)

# %% [markdown]
# ### 원본 사진 색 살려서

# %%
from wordcloud import ImageColorGenerator
image_colors = ImageColorGenerator(alice_coloring)

# %%
plt.figure(figsize=(12,12))
# wordcloud_3.recolr(ImageColorGenerator(numpy이미지 파일))
plt.imshow(wordcolud_3.recolor(color_func=image_colors))
plt.axis('off')
# Out:
# (-0.5, 419.5, 287.5, -0.5)

# %% [markdown]
# # KoNLPy

# %%
import nltk

# %%
from konlpy.tag import Twitter, Kkma
from konlpy.tag import Kkma

# %%
text = open("우리.txt",encoding = "utf-8").read()

# %%
tw = Twitter()

# %%
kkma = Kkma()

# %%
kkma.pos(text)
# Out:
# [('이', 'MDT'),
#  ('예지', 'NNG'),
#  (',', 'SP'),
#  ('박', 'NNG'),
#  ('주희', 'UN'),
#  (',', 'SP'),
#  ('정일', 'NNP'),
#  ('균', 'NNG'),
#  (',', 'SP'),
#  ('차', 'NNG'),
#  ('재성', 'NNG'),
#  (',', 'SP'),
#  ('어', 'VV'),
#  ('ㅁ', 'ETN'),
#  ('유진', 'NNG'),
#  (',', 'SP'),
#  ('...', 'SE'),
#  ('님', 'NNG'),
#  ('과', 'JKM'),
#  ('카카오', 'NNG'),
#  ('톡', 'MAG'),
#  ('대화', 'NNG'),
#  ('저장', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('날짜', 'NNG'),
#  (':', 'SP'),
#  ('2018-01', 'OL'),
#  ('-11', 'NR'),
#  ('17', 'NR'),
#  (':', 'SP'),
#  ('33', 'NR'),
#  (':', 'SP'),
#  ('30', 'NR'),
#  ('--', 'EMO'),
#  ('--', 'EMO'),
#  ('--', 'EMO'),
#  ('--', 'EMO'),
#  ('--', 'EMO'),
#  ('--', 'EMO'),
#  ('--', 'EMO'),
#  ('-', 'SW'),
#  ('2018', 'NR'),
#  ('년', 'NNM'),
#  ('1', 'NR'),
#  ('월', 'NNM'),
#  ('10', 'NR'),
#  ('일', 'NNM'),
#  ('수요일', 'NNG'),
#  ('--', 'EMO'),
#  ('--', 'EMO'),
#  ('--', 'EMO'),
#  ('--', 'EMO'),
#  ('--', 'EMO'),
#  ('--', 'EMO'),
#  ('--', 'EMO'),
#  ('-', 'SW'),
#  ('정일', 'NNP'),
#  ('균', 'NNG'),
#  ('님', 'XSN'),
#  ('이', 'JKS'),
#  ('차', 'NNG'),
#  ('재성', 'NNG'),
#  ('님', 'XSN'),
#  (',', 'SP'),
#  ('차', 'NNG'),
#  ('재성', 'NNG'),
#  ('님', 'XSN'),
#  (',', 'SP'),
#  ('조', 'NNG'),
#  ('현기', 'NNG'),
#  ('님', 'XSN'),
#  (',', 'SP'),
#  ('차', 'NNG'),
#  ('재성', 'NNG'),
#  ('님', 'XSN'),
#  (',', 'SP'),
#  ('조', 'NNG'),
#  ('현기', 'NNG'),
#  ('님', 'XSN'),
#  (',', 'SP'),
#  ('이', 'MDT'),
#  ('예지', 'NNG'),
#  ('님', 'XSN'),
#  (',', 'SP'),
#  ('차', 'NNG'),
#  ('재성', 'NNG'),
#  ('님', 'XSN'),
#  (',', 'SP'),
#  ('조', 'NNG'),
#  ('현기', 'NNG'),
#  ('님', 'XSN'),
#  (',', 'SP'),
#  ('이', 'MDT'),
#  ('예지', 'NNG'),
#  ('님', 'XSN'),
#  (',', 'SP'),
#  ('어', 'VV'),
#  ('ㅁ', 'ETN'),
#  ('유진', 'NNG'),
#  ('님', 'NNB'),
#  (',', 'SP'),
#  ('차', 'NNG'),
#  ('재성', 'NNG'),
#  ('님', 'XSN'),
#  (',', 'SP'),
#  ('조', 'NNG'),
#  ('현기', 'NNG'),
#  ('님', 'XSN'),
#  (',', 'SP'),
#  ('이', 'MDT'),
#  ('예지', 'NNG'),
#  ('님', 'XSN'),
#  (',', 'SP'),
#  ('어', 'VV'),
#  ('ㅁ', 'ETN'),
#  ('유진', 'NNG'),
#  ('님', 'NNB'),
#  (',', 'SP'),
#  ('박주', 'NNG'),
#  ('희님', 'UN'),
#  (',', 'SP'),
#  ('차', 'NNG'),
#  ('재성', 'NNG'),
#  ('님', 'XSN'),
#  (',', 'SP'),
#  ('조', 'NNG'),
#  ('현기', 'NNG'),
#  ('님', 'XSN'),
#  (',', 'SP'),
#  ('이', 'MDT'),
#  ('예지', 'NNG'),
#  ('님', 'XSN'),
#  (',', 'SP'),
#  ('어', 'VV'),
#  ('ㅁ', 'ETN'),
#  ('유진', 'NNG'),
#  ('님', 'NNB'),
#  (',', 'SP'),
#  ('박주', 'NNG'),
#  ('희님', 'UN'),
#  (',', 'SP'),
#  ('민정', 'NNG'),
#  ('원님', 'NNG'),
#  ('을', 'JKO'),
#  ('초대', 'NNG'),
#  ('하', 'XSV'),
#  ('였', 'EPT'),
#  ('습니다', 'EFN'),
#  ('.', 'SF'),
#  ('[', 'SS'),
#  ('정일', 'NNP'),
#  ('균', 'NNG'),
#  (']', 'SS'),
#  ('[', 'SS'),
#  ('오후', 'NNG'),
#  ('5', 'NR'),
#  (':', 'SP'),
#  ('19', 'NR'),
#  (']', 'SS'),
#  ('자료', 'NNG'),
#  ('업', 'NNG'),
#  ('로드', 'NNG'),
#  ('[', 'SS'),
#  ('정일', 'NNP'),
#  ('균', 'NNG'),
#  (']', 'SS'),
#  ('[', 'SS'),
#  ('오후', 'NNG'),
#  ('5', 'NR'),
#  (':', 'SP'),
#  ('19', 'NR'),
#  (']', 'SS'),
#  ('http', 'OL'),
#  (':', 'SP'),
#  ('//', 'SW'),
#  ('www', 'OL'),
#  ('.', 'SF'),
#  ('ekn', 'OL'),
#  ('.', 'SF'),
#  ('kr', 'OL'),
#  ('/', 'SP'),
#  ('news', 'OL'),
#  ('/', 'SP'),
#  ('article', 'OL'),
#  ('.', 'SF'),
#  ('html', 'OL'),
#  ('?', 'SF'),
#  ('no', 'OL'),
#  ('=', 'SW'),
#  ('254131', 'NR'),
#  ('[', 'SS'),
#  ('조', 'NNG'),
#  ('현기', 'NNG'),
#  (']', 'SS'),
#  ('[', 'SS'),
#  ('오후', 'NNG'),
#  ('5', 'NR'),
#  (':', 'SP'),
#  ('24', 'NR'),
#  (']', 'SS'),
#  ('[', 'SS'),
#  ('FILE', 'OL'),
#  (']', 'SS'),
#  ('회의록', 'NNG'),
#  ('180109', 'NR'),
#  ('.', 'SF'),
#  ('docx', 'OL'),
#  ('(', 'SS'),
#  ('20.13', 'NR'),
#  ('KB', 'OL'),
#  (')', 'SS'),
#  ('[', 'SS'),
#  ('조', 'NNG'),
#  ('현기', 'NNG'),
#  (']', 'SS'),
#  ('[', 'SS'),
#  ('오후', 'NNG'),
#  ('5', 'NR'),
#  (':', 'SP'),
#  ('54', 'NR'),
#  (']', 'SS'),
#  ('http', 'OL'),
#  (':', 'SP'),
#  ('//', 'SW'),
#  ('franchise', 'OL'),
#  ('.', 'SF'),
#  ('ftc', 'OL'),
#  ('.', 'SF'),
#  ('go', 'OL'),
#  ('.', 'SF'),
#  ('kr', 'OL'),
#  ('/', 'SP'),
#  ('user', 'OL'),
#  ('/', 'SP'),
#  ('extra', 'OL'),
#  ('/', 'SP'),
#  ('main', 'OL'),
#  ('/', 'SP'),
#  ('62', 'NR'),
#  ('/', 'SP'),
#  ('firMst', 'OL'),
#  ('/', 'SP'),
#  ('list', 'OL'),
#  ('/', 'SP'),
#  ('jsp', 'OL'),
#  ('/', 'SP'),
#  ('LayOutPage', 'OL'),
#  ('.', 'SF'),
#  ('do', 'OL'),
#  ('[', 'SS'),
#  ('조', 'NNG'),
#  ('현기', 'NNG'),
#  (']', 'SS'),
#  ('[', 'SS'),
#  ('오후', 'NNG'),
#  ('5', 'NR'),
#  (':', 'SP'),
#  ('57', 'NR'),
#  (']', 'SS'),
#  ('YOLO', 'OL'),
#  ('족', 'NNG'),
#  (',', 'SP'),
#  ('가심', 'NNG'),
#  ('비', 'NNG'),
#  (',', 'SP'),
#  ('플라시', 'NNG'),
#  ('보', 'XSN'),
#  ('소비', 'NNG'),
#  (',', 'SP'),
#  ('엠티', 'NNG'),
#  (',', 'SP'),
#  ('MT', 'OL'),
#  (',', 'SP'),
#  ('가성', 'NNG'),
#  ('비', 'NNG'),
#  (',', 'SP'),
#  ('싸', 'VA'),
#  ('다', 'ECS'),
#  (',', 'SP'),
#  ('맛', 'NNG'),
#  (',', 'SP'),
#  ('가볍', 'VA'),
#  ('다', 'ECS'),
#  (',', 'SP'),
#  ('쓰', 'VV'),
#  ('다', 'ECS'),
#  (',', 'SP'),
#  ('수입', 'NNG'),
#  ('맥주', 'NNG'),
#  (',', 'SP'),
#  ('코끼리', 'NNG'),
#  (',', 'SP'),
#  ('녹색', 'NNG'),
#  (',', 'SP'),
#  ('초록색', 'NNG'),
#  (',', 'SP'),
#  ('필', 'NNG'),
#  ('리', 'XSN'),
#  (',', 'SP'),
#  ('발포', 'NNG'),
#  ('주', 'NNG'),
#  (',', 'SP'),
#  ('맥주', 'NNG'),
#  (',', 'SP'),
#  ('소맥', 'NNG'),
#  (',', 'SP'),
#  ('도수', 'NNG'),
#  (',', 'SP'),
#  ('쓴맛', 'NNG'),
#  (',', 'SP'),
#  ('알코올', 'NNG'),
#  (',', 'SP'),
#  ('알콜', 'NNG'),
#  (',', 'SP'),
#  ('주류', 'NNG'),
#  (',', 'SP'),
#  ('즐겁', 'VA'),
#  ('다', 'ECS'),
#  (',', 'SP'),
#  ('신나', 'VV'),
#  ('다', 'ECS'),
#  (',', 'SP'),
#  ('취하', 'VV'),
#  ('ㄴ다', 'ECS'),
#  (',', 'SP'),
#  ('청량감', 'NNG'),
#  (',', 'SP'),
#  ('혼', 'NNG'),
#  ('술', 'NNG'),
#  (',', 'SP'),
#  ('혼', 'NNG'),
#  ('맥', 'NNG'),
#  (',', 'SP'),
#  ('상큼', 'MAG'),
#  (',', 'SP'),
#  ('상큼', 'XR'),
#  ('하', 'XSA'),
#  ('ㄴ', 'ETD'),
#  (',', 'SP'),
#  ('상큼', 'MAG'),
#  ('하다', 'NNP'),
#  (',', 'SP'),
#  ('청정', 'NNG'),
#  (',', 'SP'),
#  ('깨끗', 'XR'),
#  ('하', 'XSA'),
#  ('ㅁ', 'ETN'),
#  (',', 'SP'),
#  ('물', 'NNG'),
#  ('탐', 'NNG'),
#  (',', 'SP'),
#  ('물', 'NNG'),
#  ('타', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('맛', 'NNG'),
#  (',', 'SP'),
#  ('물', 'NNG'),
#  ('타', 'VV'),
#  ('었', 'EPT'),
#  ('네', 'EFN'),
#  (',', 'SP'),
#  ('물', 'NNG'),
#  (',', 'SP'),
#  ('피', 'NNG'),
#  ('츠', 'UN'),
#  (',', 'SP'),
#  ('호랑이', 'NNG'),
#  (',', 'SP'),
#  ('조', 'NNG'),
#  ('정석', 'NNG'),
#  (',', 'SP'),
#  ('망고', 'NNG'),
#  ('링', 'NNG'),
#  ('고', 'XSN'),
#  (',', 'SP'),
#  ('쓰', 'VV'),
#  ('어', 'ECS'),
#  ('머스', 'UN'),
#  ('비', 'NNG'),
#  (',', 'SP'),
#  ('주류', 'NNG'),
#  ('세', 'NNG'),
#  (',', 'SP'),
#  ('발아', 'NNG'),
#  (',', 'SP'),
#  ('세금', 'NNG'),
#  (',', 'SP'),
#  ('비싸', 'VA'),
#  ('다', 'ECS'),
#  (',', 'SP'),
#  ('탕진', 'NNG'),
#  (',', 'SP'),
#  ('탕진', 'NNG'),
#  ('잼', 'NNG'),
#  (',', 'SP'),
#  ('20', 'NR'),
#  ('대', 'NNM'),
#  (',', 'SP'),
#  ('라이프', 'NNG'),
#  ('스타일', 'NNG'),
#  (',', 'SP'),
#  ('소비', 'NNG'),
#  ('패턴', 'NNG'),
#  (',', 'SP'),
#  ('달', 'VA'),
#  ('다', 'ECS'),
#  (',', 'SP'),
#  ('독서실', 'NNG'),
#  (',', 'SP'),
#  ('소음', 'NNG'),
#  (',', 'SP'),
#  ('카', 'NNG'),
#  ('공', 'NNG'),
#  (',', 'SP'),
#  ('원두', 'NNG'),
#  (',', 'SP'),
#  ('다이어리', 'NNG'),
#  (',', 'SP'),
#  ('득', 'NNG'),
#  ('템', 'NNB'),
#  (',', 'SP'),
#  ('개', 'NNG'),
#  ('이득', 'NNG'),
#  (',', 'SP'),
#  ('굳', 'VV'),
#  (',', 'SP'),
#  ('분위기', 'NNG'),
#  (',', 'SP'),
#  ('음악', 'NNG'),
#  (',', 'SP'),
#  ('의자', 'NNG'),
#  (',', 'SP'),
#  ('조명', 'NNG'),
#  (',', 'SP'),
#  ('저', 'NP'),
#  ('의', 'JKG'),
#  ('3', 'NR'),
#  ('맥주', 'NNG'),
#  (',', 'SP'),
#  ('홀더', 'NNG'),
#  (',', 'SP'),
#  ('컵', 'NNG'),
#  ('홀더', 'NNG'),
#  (',', 'SP'),
#  ('테이크', 'NNG'),
#  ('아웃', 'NNG'),
#  (',', 'SP'),
#  ('컵', 'NNG'),
#  ('홀더', 'NNG'),
#  (',', 'SP'),
#  ('테이크', 'NNG'),
#  ('아웃', 'NNG'),
#  (',', 'SP'),
#  ('코끼리', 'NNG'),
#  ('맥주', 'NNG'),
#  (',', 'SP'),
#  ('즐기', 'VV'),
#  ('다', 'ECS'),
#  (',', 'SP'),
#  ('아', 'VV'),
#  ('아', 'ECD'),
#  (',', 'SP'),
#  ('한잔', 'NNG'),
#  (',', 'SP'),
#  ('혼자', 'NNG'),
#  (',', 'SP'),
#  ('근처', 'NNG'),
#  (',', 'SP'),
#  ('가깝', 'VA'),
#  ('다', 'ECS'),
#  (',', 'SP'),
#  ('행복', 'NNG'),
#  (',', 'SP'),
#  ('편하', 'VA'),
#  ('다', 'ECS'),
#  (',', 'SP'),
#  ('지리', 'VV'),
#  ('었', 'EPT'),
#  ('다', 'ECS'),
#  (',', 'SP'),
#  ('퇴근', 'NNG'),
#  (',', 'SP'),
#  ('추억', 'NNG'),
#  (',', 'SP'),
#  ('수업', 'NNG'),
#  (',', 'SP'),
#  ('오', 'NNG'),
#  ('지구', 'NNG'),
#  ('요', 'JX'),
#  (',', 'SP'),
#  ('오지', 'VV'),
#  ('었', 'EPT'),
#  ('다', 'ECS'),
#  (',', 'SP'),
#  ('오지', 'VV'),
#  ('었', 'EPT'),
#  ('다', 'ECS'),
#  ('리', 'NNG'),
#  (',', 'SP'),
#  ('실화', 'NNG'),
#  ('이', 'VCP'),
#  ('냐', 'EFQ'),
#  (',', 'SP'),
#  ('린', 'UN'),
#  ('정', 'NNG'),
#  (',', 'SP'),
#  ('크', 'VA'),
#  ('어', 'ECS'),
#  ('엽', 'NNM'),
#  (',', 'SP'),
#  ('인정', 'NNG'),
#  (',', 'SP'),
#  ('연비', 'NNG'),
#  (',', 'SP'),
#  ('승차감', 'NNG'),
#  (',', 'SP'),
#  ('그립', 'NNG'),
#  ('감', 'XSN'),
#  (',', 'SP'),
#  ('엔진', 'NNG'),
#  (',', 'SP'),
#  ('외국인', 'NNG'),
#  (',', 'SP'),
#  ('외국인', 'NNG'),
#  ('필', 'NNG'),
#  ('라이트', 'NNG'),
#  (',', 'SP'),
#  ('필', 'NNG'),
#  ('라이트', 'NNG'),
#  ('에', 'JKM'),
#  ('대하', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('외국인', 'NNG'),
#  ('의', 'JKG'),
#  ('견해', 'NNG'),
#  (',', 'SP'),
#  ('스트레스', 'NNG'),
#  (',', 'SP'),
#  ('조아', 'NNG'),
#  (',', 'SP'),
#  ('조하', 'NNG'),
#  (',', 'SP'),
#  ('됴아', 'UN'),
#  (',', 'SP'),
#  ('디', 'VV'),
#  ('어', 'ECS'),
#  ('아', 'VV'),
#  ('아', 'ECS'),
#  (',', 'SP'),
#  ('개', 'NNG'),
#  ('쩔', 'VV'),
#  ('어', 'ECD'),
#  (',', 'SP'),
#  ('쩔', 'VV'),
#  ('어', 'ECD'),
#  (',', 'SP'),
#  ('헐', 'VV'),
#  ('ㄹ', 'ETD'),
#  (',', 'SP'),
#  ('대박', 'NNG'),
#  (',', 'SP'),
#  ('대박', 'NNG'),
#  ('사건', 'NNG'),
#  (',', 'SP'),
#  ('프라임', 'NNG'),
#  ('드래프트', 'NNG'),
#  (',', 'SP'),
#  ('프라임', 'NNG'),
#  ('드래프트', 'NNG'),
#  (',', 'SP'),
#  ('맥주', 'NNG'),
#  ('축제', 'NNG'),
#  (',', 'SP'),
#  ('클럽', 'NNG'),
#  (',', 'SP'),
#  ('맥주', 'NNG'),
#  ('판매', 'NNG'),
#  (',', 'SP'),
#  ('치', 'NNG'),
#  ('맥', 'NNG'),
#  (',', 'SP'),
#  ('탄', 'NNG'),
#  ('산주', 'NNG'),
#  (',', 'SP'),
#  ('알쓰', 'UN'),
#  (',', 'SP'),
#  ('홈', 'NNG'),
#  ('술', 'NNG'),
#  (',', 'SP'),
#  ('홈', 'NNG'),
#  ('술', 'NNG'),
#  ('족', 'NNG'),
#  (',', 'SP'),
#  ('홈', 'NNG'),
#  ('술', 'NNG'),
#  ('인테리어', 'NNG'),
#  (',', 'SP'),
#  ('홈', 'NNG'),
#  ('바', 'NNG'),
#  (',', 'SP'),
#  ('탕진', 'NNG'),
#  ('잼', 'NNG'),
#  (',', 'SP'),
#  ('시', 'NNG'),
#  ('발', 'NNG'),
#  ('비용', 'NNG'),
#  (',', 'SP'),
#  ('취향', 'NNG'),
#  (',', 'SP'),
#  ('취향', 'NNG'),
#  ('타', 'VV'),
#  ('다', 'ECS'),
#  (',', 'SP'),
#  ('혼', 'NNG'),
#  ('맥', 'NNG'),
#  ('족', 'NNG'),
#  (',', 'SP'),
#  ('에일', 'NNG'),
#  (',', 'SP'),
#  ('라', 'NNG'),
#  ('그', 'VV'),
#  ('어', 'ECS'),
#  (',', 'SP'),
#  ('IPA', 'OL'),
#  (',', 'SP'),
#  ('크래프트', 'NNG'),
#  ('맥주', 'NNG'),
#  (',', 'SP'),
#  ('맥주', 'NNG'),
#  ('전용', 'NNG'),
#  ('잔', 'NNG'),
#  (',', 'SP'),
#  ('맥주잔', 'NNG'),
#  ('디자인', 'NNG'),
#  (',', 'SP'),
#  ('맥주잔', 'NNG'),
#  (',', 'SP'),
#  ('전용', 'NNG'),
#  ('잔', 'NNG'),
#  (',', 'SP'),
#  ('북', 'NNG'),
#  ('토크', 'NNG'),
#  (',', 'SP'),
#  ('강연', 'NNG'),
#  (',', 'SP'),
#  ('작가', 'NNG'),
#  (',', 'SP'),
#  ('작가', 'NNG'),
#  ('와', 'JKM'),
#  ('의', 'JKG'),
#  ('대화', 'NNG'),
#  (',', 'SP'),
#  ('소설', 'NNG'),
#  ('작가', 'NNG'),
#  (',', 'SP'),
#  ('작가', 'NNG'),
#  ('대화', 'NNG'),
#  (',', 'SP'),
#  ('전공', 'NNG'),
#  ('강의', 'NNG'),
#  (',', 'SP'),
#  ('카페', 'NNG'),
#  ('강의', 'NNG'),
#  (',', 'SP'),
#  ('카페', 'NNG'),
#  ('수업', 'NNG'),
#  (',', 'SP'),
#  ('카페', 'NNG'),
#  ('교류', 'NNG'),
#  (',', 'SP'),
#  ('교환', 'NNG'),
#  (',', 'SP'),
#  ('교류', 'NNG'),
#  (',', 'SP'),
#  ('북', 'NNG'),
#  ('클럽', 'NNG'),
#  (',', 'SP'),
#  ('책', 'NNG'),
#  ('카페', 'NNG'),
#  (',', 'SP'),
#  ('책읽기', 'NNG'),
#  (',', 'SP'),
#  ('기', 'NNG'),
#  ('프', 'UN'),
#  ('티', 'NNG'),
#  ('콘', 'NNG'),
#  (',', 'SP'),
#  ('기', 'NNG'),
#  ('프트', 'UN'),
#  ('카드', 'NNG'),
#  (',', 'SP'),
#  ('사이렌', 'NNG'),
#  ('오더', 'NNG'),
#  (',', 'SP'),
#  ('응원', 'NNG'),
#  ('선물', 'NNG'),
#  (',', 'SP'),
#  ('팀', 'NNG'),
#  ('플', 'UN'),
#  (',', 'SP'),
#  ('개인', 'NNG'),
#  ('작업', 'NNG'),
#  (',', 'SP'),
#  ('개인', 'NNG'),
#  ('공부', 'NNG'),
#  (',', 'SP'),
#  ('소음', 'NNG'),
#  (',', 'SP'),
#  ('예민', 'XR'),
#  (',', 'SP'),
#  ('눈치', 'NNG'),
#  (',', 'SP'),
#  ('분위기', 'NNG'),
#  (',', 'SP'),
#  ('무드', 'NNG'),
#  (',', 'SP'),
#  ('느낌', 'NNG'),
#  (',', 'SP'),
#  ('노', 'NNG'),
#  ('맛', 'NNG'),
#  (',', 'SP'),
#  ('노', 'NNG'),
#  ('잼', 'NNG'),
#  (',', 'SP'),
#  ('노', 'NNG'),
#  ('어이', 'MAG'),
#  (',', 'SP'),
#  ('디저트', 'NNG'),
#  (',', 'SP'),
#  ('케이꾸', 'UN'),
#  (',', 'SP'),
#  ('창', 'NNG'),
#  ('업자', 'NNG'),
#  (',', 'SP'),
#  ('창업', 'NNG'),
#  (',', 'SP'),
#  ('귀엽', 'VA'),
#  ('다', 'ECS'),
#  (',', 'SP'),
#  ('갤러리', 'NNG'),
#  ('아', 'XSN'),
#  (',', 'SP'),
#  ('물', 'NNG'),
#  ('맥주', 'NNG'),
#  (',', 'SP'),
#  ('낮', 'VA'),
#  ('은', 'ETD'),
#  ('농도', 'NNG'),
#  (',', 'SP'),
#  ('옅', 'VA'),
#  ('은', 'ETD'),
#  (',', 'SP'),
#  ('싸', 'VA'),
#  ('ㄴ', 'ETD'),
#  ('맛', 'NNG'),
#  (',', 'SP'),
#  ('싸구려', 'NNG'),
#  (',', 'SP'),
#  ('구', 'XPN'),
#  ('리다', 'NNP'),
#  (',', 'SP'),
#  ('구리', 'NNG'),
#  ('네', 'XSN'),
#  (',', 'SP'),
#  ('목', 'NNG'),
#  ('넘기', 'VV'),
#  ('ㅁ', 'ETN'),
#  (',', 'SP'),
#  ('비추', 'NNG'),
#  (',', 'SP'),
#  ('강추', 'NNG'),
#  (',', 'SP'),
#  ('탈락', 'NNG'),
#  (',', 'SP'),
#  ('성공', 'NNG'),
#  (',', 'SP'),
#  ('추억', 'NNG'),
#  (',', 'SP'),
#  ('새내기', 'NNG'),
#  (',', 'SP'),
#  ('대학생', 'NNG'),
#  (',', 'SP'),
#  ('1', 'NR'),
#  ('학년', 'NNG'),
#  (',', 'SP'),
#  ('모임', 'NNG'),
#  (',', 'SP'),
#  ('2', 'NR'),
#  ('학년', 'NNG'),
#  (',', 'SP'),
#  ('3', 'NR'),
#  ('학년', 'NNG'),
#  (',', 'SP'),
#  ('4', 'NR'),
#  ('학년', 'NNG'),
#  (',', 'SP'),
#  ('고시생', 'NNG'),
#  (',', 'SP'),
#  ('공무원', 'NNG'),
#  (',', 'SP'),
#  ('핫', 'NNG'),
#  ('플', 'UN'),
#  (',', 'SP'),
#  ('핫', 'NNG'),
#  ('하다', 'NNP'),
#  (',', 'SP'),
#  ('피곤', 'NNG'),
#  ('하', 'XSV'),
#  ('어', 'ECS'),
#  (',', 'SP'),
#  ('열', 'NNG'),
#  ('공', 'NNG'),
#  (',', 'SP'),
#  ('혈', 'NNG'),
#  ('공', 'NNG'),
#  (',', 'SP'),
#  ('가', 'VV'),
#  ('아', 'ECS'),
#  ('즈', 'UN'),
#  ('아', 'VV'),
#  ('아', 'ECS'),
#  (',', 'SP'),
#  ('ㅇ', 'NNG'),
#  ('ㅈ', 'NNG'),
#  (',', 'SP'),
#  ('힐링', 'NNG'),
#  (',', 'SP'),
#  ('취업', 'NNG'),
#  (',', 'SP'),
#  ('연애', 'NNG'),
#  (',', 'SP'),
#  ('놀', 'VV'),
#  ('기', 'ETN'),
#  (',', 'SP'),
#  ('먹', 'VV'),
#  ('기', 'ETN'),
#  (',', 'SP'),
#  ('여행', 'NNG'),
#  (',', 'SP'),
#  ('나', 'NP'),
#  ('를', 'JKO'),
#  ('위하', 'VV'),
#  ('ㄴ', 'ETD'),
#  (',', 'SP'),
#  ('선물', 'NNG'),
#  (',', 'SP'),
#  ('나', 'NP'),
#  ('만', 'JX'),
#  ('의', 'JKG'),
#  ('시간', 'NNG'),
#  (',', 'SP'),
#  ('나', 'NP'),
#  ('혼자', 'NNG'),
#  (',', 'SP'),
#  ('혼자', 'NNG'),
#  (',', 'SP'),
#  ('거지', 'NNG'),
#  (',', 'SP'),
#  ('돈', 'NNG'),
#  ('없', 'VA'),
#  ('어', 'ECD'),
#  (',', 'SP'),
#  ('돈', 'NNG'),
#  ('없', 'VA'),
#  ('음', 'ETN'),
#  (',', 'SP'),
#  ('버겁', 'VA'),
#  ('다', 'ECS'),
#  (',', 'SP'),
#  ('지치', 'VV'),
#  ('ㄴ다', 'ECS'),
#  (',', 'SP'),
#  ('지치', 'VV'),
#  ('어', 'ECS'),
#  (',', 'SP'),
#  ('밤샘', 'NNG'),
#  (',', 'SP'),
#  ('내적', 'NNG'),
#  ('댄스', 'NNG'),
#  (',', 'SP'),
#  ('외롭', 'VA'),
#  ('다', 'ECS'),
#  (',', 'SP'),
#  ('첫술', 'NNG'),
#  (',', 'SP'),
#  ('인생', 'NNG'),
#  ('첫술', 'NNG'),
#  (',', 'SP'),
#  ('인생', 'NNG'),
#  ('술', 'NNG'),
#  (',', 'SP'),
#  ('첫', 'MDT'),
#  ('맥주', 'NNG'),
#  (',', 'SP'),
#  ('이', 'VCP'),
#  ('ㄴ', 'ETD'),
#  ('생맥주', 'NNG'),
#  (',', 'SP'),
#  ('왜', 'MAG'),
#  ('마시', 'VV'),
#  ('어', 'ECS'),
#  (',', 'SP'),
#  ('술', 'NNG'),
#  ('왜', 'MAG'),
#  ('마시', 'VV'),
#  ('어', 'ECS'),
#  (',', 'SP'),
#  ('과시', 'NNG'),
#  (',', 'SP'),
#  ('셀', 'NNG'),
#  ('카', 'NNG'),
#  (',', 'SP'),
#  ('막', 'MAG'),
#  ('장', 'NNG'),
#  (',', 'SP'),
#  ('노', 'NNG'),
#  ('답', 'NNG'),
#  (',', 'SP'),
#  ('군대', 'NNG'),
#  ('생각', 'NNG'),
#  (',', 'SP'),
#  ('노', 'NNG'),
#  ('키즈', 'NNG'),
#  ('존', 'NNP'),
#  (',', 'SP'),
#  ('애', 'NNG'),
#  ('들', 'XSN'),
#  (',', 'SP'),
#  ('시끄럽', 'VA'),
#  ('어', 'ECS'),
#  (',', 'SP'),
#  ('신', 'NNG'),
#  ('메뉴', 'NNG'),
#  (',', 'SP'),
#  ('월요일', 'NNG'),
#  (',', 'SP'),
#  ('월욜', 'NNG'),
#  (',', 'SP'),
#  ('화욜', 'NNG'),
#  (',', 'SP'),
#  ('수욜', 'NNG'),
#  (',', 'SP'),
#  ('목욜', 'NNG'),
#  (',', 'SP'),
#  ('금욜', 'NNG'),
#  (',', 'SP'),
#  ('불금', 'NNG'),
#  (',', 'SP'),
#  ('불토', 'NNG'),
#  (',', 'SP'),
#  ('월요병', 'NNG'),
#  (',', 'SP'),
#  ('점심', 'NNG'),
#  (',', 'SP'),
#  ('저녁', 'NNG'),
#  (',', 'SP'),
#  ('든든', 'XR'),
#  (',', 'SP'),
#  ('비트', 'NNG'),
#  ('코', 'NNG'),
#  ('인', 'NNG'),
#  (',', 'SP'),
#  ('해시', 'NNG'),
#  ('태그', 'NNG'),
#  (',', 'SP'),
#  ('#', 'SW'),
#  (',', 'SP'),
#  ('무겁', 'VA'),
#  ('ㄴ', 'ETD'),
#  (',', 'SP'),
#  ('중후', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  (',', 'SP'),
#  ('진한', 'NNG'),
#  (',', 'SP'),
#  ('찐하', 'VA'),
#  ('ㄴ', 'ETD'),
#  (',', 'SP'),
#  ('반', 'NNG'),
#  ('오십', 'NR'),
#  (',', 'SP'),
#  ('민짜', 'NNG'),
#  (',', 'SP'),
#  ('민', 'NNG'),
#  ('증', 'NNG'),
#  ('검사', 'NNG'),
#  (',', 'SP'),
#  ('일탈', 'NNG'),
#  (',', 'SP'),
#  ('--', 'EMO'),
#  ('--', 'EMO'),
#  ('--', 'EMO'),
#  ('--', 'EMO'),
#  ('--', 'EMO'),
#  ('--', 'EMO'),
#  ('--', 'EMO'),
#  ('-', 'SW'),
#  ('2018', 'NR'),
#  ...]

# %%
kkma.nouns(text)
# Out:
# ['예지',
#  '박',
#  '박주희',
#  '주희',
#  '정일',
#  '정일균',
#  '균',
#  '차',
#  '차재성',
#  '재성',
#  '유진',
#  '님',
#  '카카오',
#  '대화',
#  '저장',
#  '날짜',
#  '-11',
#  '17',
#  '33',
#  '30',
#  '2018',
#  '2018년',
#  '년',
#  '1',
#  '1월',
#  '월',
#  '10',
#  '10일',
#  '일',
#  '수요일',
#  '조',
#  '조현기',
#  '현기',
#  '유진님',
#  '님',
#  '박주',
#  '박주희님',
#  '희님',
#  '민정',
#  '민정원님',
#  '원님',
#  '초대',
#  '오후',
#  '5',
#  '19',
#  '자료',
#  '자료업로드',
#  '업',
#  '로드',
#  '254131',
#  '24',
#  '회의록',
#  '회의록180109',
#  '180109',
#  '20.13',
#  '54',
#  '62',
#  '57',
#  '족',
#  '가심',
#  '가심비',
#  '비',
#  '플라시',
#  '소비',
#  '엠티',
#  '가성',
#  '가성비',
#  '맛',
#  '수입',
#  '수입맥주',
#  '맥주',
#  '코끼리',
#  '녹색',
#  '초록색',
#  '필',
#  '발포',
#  '발포주',
#  '주',
#  '소맥',
#  '도수',
#  '쓴맛',
#  '알코올',
#  '알콜',
#  '주류',
#  '청량감',
#  '혼',
#  '혼술',
#  '술',
#  '혼맥',
#  '맥',
#  '하다',
#  '청정',
#  '물',
#  '물탐',
#  '탐',
#  '피',
#  '피츠',
#  '츠',
#  '호랑이',
#  '조정석',
#  '정석',
#  '망고',
#  '망고링',
#  '링',
#  '머스',
#  '머스비',
#  '주류세',
#  '세',
#  '발아',
#  '세금',
#  '탕진',
#  '탕진잼',
#  '잼',
#  '20',
#  '20대',
#  '대',
#  '라이프',
#  '스타일',
#  '패턴',
#  '독서실',
#  '소음',
#  '카',
#  '카공',
#  '공',
#  '원두',
#  '다이어리',
#  '득',
#  '득템',
#  '템',
#  '개',
#  '개이득',
#  '이득',
#  '분위기',
#  '음악',
#  '의자',
#  '조명',
#  '저',
#  '3',
#  '3맥주',
#  '홀더',
#  '컵',
#  '컵홀더',
#  '테이크',
#  '아웃',
#  '테이크아웃',
#  '코끼리맥주',
#  '한잔',
#  '혼자',
#  '근처',
#  '행복',
#  '퇴근',
#  '추억',
#  '수업',
#  '오',
#  '오지구',
#  '지구',
#  '리',
#  '실화',
#  '린',
#  '린정',
#  '정',
#  '엽',
#  '인정',
#  '연비',
#  '승차감',
#  '그립',
#  '엔진',
#  '외국인',
#  '외국인필라이트',
#  '라이트',
#  '필라이트',
#  '견해',
#  '스트레스',
#  '조아',
#  '조하',
#  '됴아',
#  '대박',
#  '대박사건',
#  '사건',
#  '프라임',
#  '프라임드래프트',
#  '드래프트',
#  '맥주축제',
#  '축제',
#  '클럽',
#  '판매',
#  '치',
#  '치맥',
#  '탄',
#  '탄산주',
#  '산주',
#  '알쓰',
#  '홈',
#  '홈술',
#  '홈술족',
#  '인테리어',
#  '홈바',
#  '바',
#  '시',
#  '시발비용',
#  '발',
#  '비용',
#  '취향',
#  '혼맥족',
#  '에일',
#  '라',
#  '크래프트',
#  '크래프트맥주',
#  '맥주전용잔',
#  '전용',
#  '잔',
#  '맥주잔',
#  '디자인',
#  '전용잔',
#  '북',
#  '북토크',
#  '토크',
#  '강연',
#  '작가',
#  '소설',
#  '소설작가',
#  '작가대화',
#  '전공',
#  '전공강의',
#  '강의',
#  '카페',
#  '카페강의',
#  '카페수업',
#  '카페교류',
#  '교류',
#  '교환',
#  '북클럽',
#  '책',
#  '책카페',
#  '책읽기',
#  '기',
#  '기프티콘',
#  '프',
#  '티',
#  '콘',
#  '기프트카드',
#  '프트',
#  '카드',
#  '사이렌',
#  '오더',
#  '응원',
#  '선물',
#  '팀',
#  '팀플',
#  '플',
#  '개인',
#  '작업',
#  '공부',
#  '눈치',
#  '무드',
#  '느낌',
#  '노',
#  '노맛',
#  '노잼',
#  '디저트',
#  '케이꾸',
#  '창',
#  '창업자',
#  '업자',
#  '창업',
#  '갤러리',
#  '물맥주',
#  '농도',
#  '싸구려',
#  '리다',
#  '구리',
#  '목',
#  '비추',
#  '강추',
#  '탈락',
#  '성공',
#  '새내기',
#  '대학생',
#  '1학년',
#  '학년',
#  '모임',
#  '2',
#  '2학년',
#  '3학년',
#  '4',
#  '4학년',
#  '고시생',
#  '공무원',
#  '핫',
#  '핫플',
#  '핫하다',
#  '피곤',
#  '열',
#  '열공',
#  '혈',
#  '혈공',
#  '즈',
#  'ㅇ',
#  'ㅇㅈ',
#  'ㅈ',
#  '힐링',
#  '취업',
#  '연애',
#  '여행',
#  '나',
#  '시간',
#  '거지',
#  '돈',
#  '밤샘',
#  '내적',
#  '내적댄스',
#  '댄스',
#  '첫술',
#  '인생',
#  '인생첫술',
#  '인생술',
#  '생맥주',
#  '과시',
#  '셀',
#  '셀카',
#  '장',
#  '노답',
#  '답',
#  '군대',
#  '군대생각',
#  '생각',
#  '노키즈존',
#  '키즈',
#  '존',
#  '애',
#  '신',
#  '신메뉴',
#  '메뉴',
#  '월요일',
#  '월',
#  '월욜',
#  '욜',
#  '화',
#  '화욜',
#  '수',
#  '수욜',
#  '목욜',
#  '금',
#  '금욜',
#  '불금',
#  '불토',
#  '월요병',
#  '점심',
#  '저녁',
#  '비트',
#  '비트코인',
#  '코',
#  '인',
#  '해시',
#  '해시태그',
#  '태그',
#  '중후',
#  '진한',
#  '반',
#  '반오십',
#  '오십',
#  '민짜',
#  '민',
#  '민증검사',
#  '증',
#  '검사',
#  '일탈',
#  '11',
#  '11일',
#  '목요일',
#  '오전',
#  '10.44',
#  '제',
#  '시스',
#  '8.93',
#  '커피',
#  '브랜드',
#  '9.91',
#  '24.35',
#  '59',
#  '13.63']

# %%
kkma.sentences('안녕하세요 조현기 입니다.')
# Out:
# ['안녕하세요', '조 현기 입니다.']

# %%
kkma.nouns('김건희입니다. 명사를 빼어 보십시오. 가능 하시겠습니까? 하하하 명사닼')
# Out:
# ['김', '김건희', '건희', '명사', '빼어', '가능', '하', '명사닼', '닼']

# %%
kkma.pos("형태소 분석, pos분석을 해보세요 하하")
# Out:
# [('형태소', 'NNG'),
#  ('분석', 'NNG'),
#  (',', 'SP'),
#  ('pos', 'OL'),
#  ('분석', 'NNG'),
#  ('을', 'JKO'),
#  ('해보', 'VV'),
#  ('세요', 'EFN'),
#  ('하하', 'MAG')]

# %%
stop_words = ['현기', '유진이', '조현기','희님']

# %%
text_nouns =tw.nouns(text)

# %%
text_nouns
# Out:
# ['이예지',
#  '박주희',
#  '정일',
#  '균',
#  '차',
#  '재성',
#  '엄유진',
#  '님',
#  '카카오',
#  '톡',
#  '대화',
#  '저장',
#  '날짜',
#  '년',
#  '월',
#  '일',
#  '수요일',
#  '정일',
#  '균',
#  '차',
#  '재성',
#  '차',
#  '재성',
#  '조현',
#  '기',
#  '차',
#  '재성',
#  '조현',
#  '기',
#  '이예지',
#  '차',
#  '재성',
#  '조현',
#  '기',
#  '이예지',
#  '엄유진',
#  '차',
#  '재성',
#  '조현',
#  '기',
#  '이예지',
#  '엄유진',
#  '박주희',
#  '차',
#  '재성',
#  '조현',
#  '기',
#  '이예지',
#  '엄유진',
#  '박주희',
#  '민정',
#  '원님',
#  '정일',
#  '균',
#  '오후',
#  '자료',
#  '업로드',
#  '정일',
#  '균',
#  '오후',
#  '조현',
#  '기',
#  '오후',
#  '회의',
#  '록',
#  '조현',
#  '기',
#  '오후',
#  '조현',
#  '기',
#  '오후',
#  '족',
#  '심비',
#  '플라시보',
#  '소비',
#  '엠티',
#  '가성',
#  '비',
#  '맛',
#  '수입',
#  '맥주',
#  '코끼리',
#  '녹색',
#  '초록색',
#  '발포주',
#  '맥주',
#  '소맥',
#  '도수',
#  '쓴맛',
#  '알코올',
#  '알콜',
#  '주류',
#  '취한',
#  '청량감',
#  '혼술',
#  '혼맥',
#  '상큼',
#  '상큼',
#  '상큼',
#  '청정',
#  '물',
#  '물탄',
#  '맛',
#  '물',
#  '물',
#  '피츠',
#  '호랑이',
#  '조정석',
#  '망고',
#  '링고',
#  '써머',
#  '스비',
#  '주류',
#  '세',
#  '발아',
#  '세금',
#  '탕진',
#  '탕진',
#  '잼',
#  '라이프',
#  '스타일',
#  '소비',
#  '패턴',
#  '달',
#  '독서실',
#  '소음',
#  '카공',
#  '원두',
#  '다이어리',
#  '득템',
#  '개이득',
#  '분위기',
#  '음악',
#  '의자',
#  '조명',
#  '제',
#  '맥주',
#  '홀더',
#  '컵홀더',
#  '테이크',
#  '아웃',
#  '컵',
#  '홀더',
#  '테이크아웃',
#  '코끼리',
#  '맥주',
#  '아아',
#  '한잔',
#  '혼자',
#  '근처',
#  '행복',
#  '지렸',
#  '퇴근',
#  '추억',
#  '수업',
#  '실화',
#  '린정',
#  '커엽',
#  '인정',
#  '연비',
#  '승',
#  '차감',
#  '감',
#  '엔진',
#  '외국인',
#  '외국인',
#  '필',
#  '라이트',
#  '필',
#  '라이트',
#  '대한',
#  '외국인',
#  '견해',
#  '스트레스',
#  '됴',
#  '뎌',
#  '개',
#  '대박',
#  '대박',
#  '사건',
#  '프라임',
#  '드래프트',
#  '프라임',
#  '드래프트',
#  '맥주',
#  '축제',
#  '클럽',
#  '맥주',
#  '판매',
#  '치맥',
#  '탄산',
#  '주',
#  '알',
#  '홈술',
#  '홈술족',
#  '홈술',
#  '인테리어',
#  '홈바',
#  '탕진',
#  '잼',
#  '시발',
#  '비용',
#  '취향',
#  '취향',
#  '혼',
#  '맥족',
#  '에일',
#  '라거',
#  '크래프트',
#  '맥주',
#  '맥주',
#  '전용',
#  '잔',
#  '맥주잔',
#  '디자인',
#  '맥주잔',
#  '전용',
#  '잔',
#  '북',
#  '토크',
#  '강연',
#  '작가',
#  '작가',
#  '대화',
#  '소설',
#  '작가',
#  '작가',
#  '대화',
#  '전공',
#  '강의',
#  '카페',
#  '강의',
#  '카페',
#  '수업',
#  '카페',
#  '교류',
#  '교환',
#  '교류',
#  '북',
#  '클럽',
#  '책',
#  '카페',
#  '책',
#  '기프티콘',
#  '기프트카드',
#  '사이렌',
#  '응원',
#  '선물',
#  '팀',
#  '개인',
#  '작업',
#  '개인',
#  '공부',
#  '소음',
#  '예민',
#  '눈치',
#  '분위기',
#  '무드',
#  '느낌',
#  '노맛',
#  '노잼',
#  '노어',
#  '디저트',
#  '케이',
#  '창업',
#  '창업',
#  '갤러리아',
#  '물',
#  '맥주',
#  '농도',
#  '옅',
#  '맛',
#  '싸구려',
#  '구리',
#  '구리',
#  '목',
#  '넘김',
#  '강추',
#  '탈락',
#  '성공',
#  '추억',
#  '새내기',
#  '대학생',
#  '학년',
#  '모임',
#  '학년',
#  '학년',
#  '학년',
#  '고시생',
#  '공무원',
#  '핫',
#  '핫',
#  '열공',
#  '혈공',
#  '가즈',
#  '힐링',
#  '취업',
#  '연애',
#  '먹기',
#  '여행',
#  '선물',
#  '나',
#  '시간',
#  '나',
#  '혼자',
#  '혼자',
#  '거지',
#  '돈',
#  '돈',
#  '밤샘',
#  '내적댄스',
#  '첫술',
#  '인생',
#  '첫술',
#  '인생',
#  '술',
#  '첫',
#  '맥주',
#  '인생',
#  '맥주',
#  '왜',
#  '술왜',
#  '과시',
#  '셀카',
#  '막장',
#  '노답',
#  '군대',
#  '생각',
#  '노',
#  '키즈',
#  '존',
#  '애',
#  '신',
#  '메뉴',
#  '월요일',
#  '월욜',
#  '화욜',
#  '수욜',
#  '목욜',
#  '금욜',
#  '불금',
#  '불토',
#  '월요병',
#  '점심',
#  '저녁',
#  '비트코인',
#  '해시',
#  '태그',
#  '중후',
#  '반',
#  '오십',
#  '민',
#  '민증',
#  '검사',
#  '일탈',
#  '년',
#  '월',
#  '일',
#  '목요일',
#  '차',
#  '재성',
#  '오전',
#  '맥주',
#  '차',
#  '재성',
#  '오전',
#  '제네시스',
#  '차',
#  '재성',
#  '오전',
#  '커피',
#  '브랜드',
#  '차',
#  '재성',
#  '오전',
#  '회의',
#  '록',
#  '조현',
#  '기',
#  '오전',
#  '자료']

# %%
text = nltk.Text(text_nouns, name='카톡')

# %%
text.vocab().most_common(30)
# Out:
# [('맥주', 12),
#  ('차', 11),
#  ('재성', 11),
#  ('조현', 9),
#  ('기', 9),
#  ('이예지', 5),
#  ('오후', 5),
#  ('오전', 5),
#  ('정일', 4),
#  ('균', 4),
#  ('엄유진', 4),
#  ('물', 4),
#  ('작가', 4),
#  ('카페', 4),
#  ('학년', 4),
#  ('박주희', 3),
#  ('대화', 3),
#  ('맛', 3),
#  ('상큼', 3),
#  ('탕진', 3),
#  ('혼자', 3),
#  ('외국인', 3),
#  ('인생', 3),
#  ('년', 2),
#  ('월', 2),
#  ('일', 2),
#  ('자료', 2),
#  ('회의', 2),
#  ('록', 2),
#  ('소비', 2)]

# %%
# 대한민국 헌법 내장 데이터
from konlpy.corpus import kolaw

# %%
ko = kolaw.open("우리.txt",encoding = "utf-8").read()

# %%
ko

# %%
from konlpy.tag import Twitter

# %%
tw = Twitter()

# %%
# 트위터 형태소 분석 후 명사만 추출
ko_nouns = tw.nouns(ko)

# %%
ko_nouns

# %%
stop_words = ['제', '월', '일','조','수','때','그','이','바','및','안']

# stop_words 빼기
ko_nouns = [word for word in ko_nouns if word not in stop_words]

# %%
ko_nouns

# %%
ko  = nltk.Text(ko_nouns, name='헌법')

# %%
# 상위 30개 수 
ko.vocab().most_common(30)

# %% [markdown]
# ### matplotlib 한글폰트

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
# nltk패키지를 통해 konlpy에서 뽑은 명사들 상위 500개 추출
data = ko.vocab().most_common(500)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-b0261fee56e5> in <module>()
#       1 # nltk패키지를 통해 konlpy에서 뽑은 명사들 상위 500개 추출
# ----> 2 data = ko.vocab().most_common(500)
#
# NameError: name 'ko' is not defined

# %%
# data를 딕셔너리 형태로 변환
tmp_data = dict(data)

# %%
data

# %%
wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
                      background_color='white'
                     ,relative_scaling =0.2).generate_from_frequencies(tmp_data)

# %%
plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis('off')

# %% [markdown]
# # 사진+워드클라우드

# %%
import numpy as np
from PIL import Image
from wordcloud import ImageColorGenerator

# %%
# 이미지파일 numpy로 읽기
korea_color = np.array(Image.open('./한국.jpg'))

# %%
image_color = ImageColorGenerator(korea_color)

# %%
plt.figure(figsize=(12,12))
plt.imshow(korea_color)
plt.axis('off')

# %%
wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
                     relative_scaling = 0.2,
                     mask = korea_color, 
                     background_color = 'white',
                     min_font_size=1, max_font_size=40).generate_from_frequencies(tmp_data)

# %%
plt.figure(figsize=(12,12))
plt.imshow(wordcloud.recolor(color_func=image_color))
plt.axis('off')

# %% [markdown]
# ---

# %%
# %reset

# %% [markdown]
# # 문제
# ### <font color='#ff0000'>직접 해보세요 :-)</font>

# %%
import numpy as np
from PIL import Image
from wordcloud import ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline

from wordcloud import WordCloud

# %%
apple_color = np.array(Image.open('./사과.jpg'))

# %%
image_color = ImageColorGenerator(apple_color)

# %%
plt.figure(figsize=(12,12))
plt.imshow(apple_color)
plt.axis('off')
# Out:
# (-0.5, 419.5, 287.5, -0.5)

# %%
wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
                     relative_scaling = 0.2,
                     , 
                     background_color = 'white',
                     min_font_size=1, max_font_size=40)

# %%
text = open("KakaoTalk_20180111_1644_32_315_group.txt",encoding = "utf-8").read()

# %%
wordcolud_2 = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',background_color = 'white', max_words=2000,mask = apple_color,
                       stopwords=stopwords)

wordcolud_2 = wordcolud_2.generate(text)

wordcolud_2.words_

# %%
import nltk

# %%
from konlpy.tag import Kkma

# %%
kkma = Kkma()

# %%
kkma.pos(text)

# %%
kkma.nouns(text)

# %%
stop_words = ['제', '월', '일','조','수','때','그','이','바','및','안']

# stop_words 빼기
ko_nouns = [word for word in ko_nouns if word not in stop_words]
